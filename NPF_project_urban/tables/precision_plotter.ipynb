# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sys
plt.rcParams['font.family'] = 'Times New Roman'
data = {
    'adbc_regular': [0.627342058
],
    'adbc_tuned': [0.627342058
],
    'ensemble_regular_rfc_adbc': [0.703985412
],
    'ensemble_regular_rfc_xgbc': [0.669489468
],
    'ensemble_tuned_rfc_adbc': [0.679241252
],
    'ensemble_tuned_rfc_xgbc': [0.593324585
],    
    'gbm_regular': [0.675523934
],
    'gbm_tuned': [0.688374736
],
    'k_means': [0.527815279
],
    'knn': [0.661555442
],
    'lrc_regular': [0.606092706
],
    'lrc_tuned': [0.605282927
],
    'mlpc_tuned': [0.602100037
],
    'naive_bayes': [0.608224696
],
    'rfc_regular': [0.699571399
],
    'rfc_tuned': [0.64345709
],
    'svc_regular': [0.597071334
],
    'svc_tuned': [0.597071334
],
    'xgbc_regular': [0.65744322
],
    'xgbc_tuned': [0.66531263
] 
}

df = pd.DataFrame(data)
df *= 100
# Melt the DataFrame to a long format
df_melted = df.melt(var_name='Model', value_name='Precision')

# Plot a bar plot with all bars in blue
plt.figure(figsize=(30, 30))
sns.barplot(x='Model', y='Precision', data=df_melted, color='tab:blue')
# plt.yscale('log')
plt.title('Precision Results', fontsize=40)
plt.xlabel('Model', fontsize=40)
plt.xticks(rotation=45, ha='right')
plt.ylabel('Precision Range', fontsize=40)
plt.xticks(fontsize=40)
plt.yticks(fontsize=40)
plt.savefig('precision.png', dpi=300)
plt.show()
