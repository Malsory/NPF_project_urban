# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# For changed, smote
data1 = {
    'adb': [0.6214285714285714],
    'rf_adb': [0.6173809523809524],
    'rf_lr': [0.675952380952381],
    'rf_xgb': [0.6761904761904762],
    'gbm': [0.7071428571428572],
    'knn': [0.7014285714285714],
    'lr': [0.518095238095238],
    'mlp': [0.6911904761904761],
    'nb': [0.4235714285714286],
    'rf': [0.6914285714285714],
    'svm': [0.45261904761904764],
    'xgb': [0.7261904761904762]
}
# For unchanged, norm
data2 = {
    'adb': [0.6318181818181818],
    'rf_adb': [0.5886363636363636],
    'rf_lr': [0.6734848484848485],
    'rf_xgb': [0.6128787878787879],
    'gbm': [0.6462121212121212],
    'knn': [0.6295454545454545],
    'lr': [0.6628787878787878],
    'mlp': [0.5893939393939394],
    'nb': [0.628030303030303],
    'rf': [0.7257575757575758],
    'svm': [0.6151515151515151],
    'xgb': [0.5424242424242425]
}
# For changed, weighted
data3 = {
    'adb': [0.5106060606060606],
    'rf_adb': [0.5628787878787879],
    'rf_lr': [0.6371212121212121],
    'rf_xgb': [0.6515151515151515],
    'gbm': [0.6378787878787879],
    'knn': [0.6310606060606061],
    'lr': [0.4765151515151515],
    'mlp': [0.6492424242424243],
    'nb': [0.6227272727272727],
    'rf': [0.5522727272727272],
    'svm': [0.578030303030303],
    'xgb': [0.6227272727272727]
}

plt.rcParams['font.family'] = 'Times New Roman'

df1 = pd.DataFrame.from_dict(data1, orient='index', columns=['Value']) * 100
df2 = pd.DataFrame.from_dict(data2, orient='index', columns=['Value']) * 100
df3 = pd.DataFrame.from_dict(data3, orient='index', columns=['Value']) * 100
# Merge the two DataFrames on common index (names)
merged_df = pd.merge(df1, df2, left_index=True, right_index=True)
merged_df = pd.merge(merged_df, df3, left_index=True, right_index=True)
merged_df['models'] = merged_df.index

# Plotting side-by-side bar plots
plt.figure()
merged_df.plot(kind='bar', width=0.9)
plt.title('Accuracies of models (CV)', fontsize=40)
plt.xlabel('Models', fontsize=30)
plt.ylabel('Accuracy (%)', fontsize=30)
plt.xticks(rotation=45)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.legend(['SMOTE', 'normal', "weighted"], loc='upper right', fontsize=15)

fig = plt.gcf()
fig.set_size_inches(25, 15)

plt.savefig('accuracies(cv).png', dpi=300)

# %%
# For changed, smote
data4 = {
    'adb': [0.6666666666666666],
    'rf_adb': [0.7450980392156863],
    'rf_lr': [0.7647058823529411],
    'rf_xgb': [0.8235294117647058],
    'gbm': [0.6862745098039216],
    'knn': [0.7254901960784313],
    'lr': [0.5882352941176471],
    'mlp': [0.45098039215686275],
    'nb': [0.49019607843137253],
    'rf': [0.7254901960784313],
    'svm': [0.45098039215686275],
    'xgb': [0.6862745098039216]
}
# For unchanged, norm
data5 = {
    'adb': [0.6551724137931034],
    'rf_adb': [0.5517241379310345],
    'rf_lr': [0.5517241379310345],
    'rf_xgb': [0.6206896551724138],
    'gbm': [0.5172413793103449],
    'knn': [0.5172413793103449],
    'lr': [0.5862068965517241],
    'mlp': [0.7241379310344828],
    'nb': [0.5172413793103449],
    'rf': [0.5862068965517241],
    'svm': [0.6206896551724138],
    'xgb': [0.8620689655172413]
}
# For changed, weighted
data6 = {
    'adb': [0.6206896551724138],
    'rf_adb': [0.5172413793103449],
    'rf_lr': [0.7241379310344828],
    'rf_xgb': [0.6206896551724138],
    'gbm': [0.6206896551724138],
    'knn': [0.6896551724137931],
    'lr': [0.41379310344827586],
    'mlp': [0.7586206896551724],
    'nb': [0.6206896551724138],
    'rf': [0.6206896551724138],
    'svm': [0.5862068965517241],
    'xgb': [0.7241379310344828]
}

df4 = pd.DataFrame.from_dict(data4, orient='index', columns=['Value']) * 100
df5 = pd.DataFrame.from_dict(data5, orient='index', columns=['Value']) * 100
df6 = pd.DataFrame.from_dict(data6, orient='index', columns=['Value']) * 100
# Merge the two DataFrames on common index (names)
merged_df = pd.merge(df4, df5, left_index=True, right_index=True)
merged_df = pd.merge(merged_df, df6, left_index=True, right_index=True)
merged_df['models'] = merged_df.index

# Plotting side-by-side bar plots
plt.figure()
merged_df.plot(kind='bar', width=0.9)
plt.title('Accuracies of models (test)', fontsize=40)
plt.xlabel('Models', fontsize=30)
plt.ylabel('Accuracy (%)', fontsize=30)
plt.xticks(rotation=45)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.legend(['SMOTE', 'normal', 'weighted'], loc='upper right', fontsize=15)

fig = plt.gcf()
fig.set_size_inches(25, 15)

plt.savefig('accuracies(test).png', dpi=300)
