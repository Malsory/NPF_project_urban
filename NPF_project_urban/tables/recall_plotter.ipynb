# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sys
plt.rcParams['font.family'] = 'Times New Roman'
data = {
    'adbc_regular': [0.625003814

],
    'adbc_tuned': [0.625003814

],
    'ensemble_regular_rfc_adbc': [0.712402746

],
    'ensemble_regular_rfc_xgbc': [0.709771167

],
    'ensemble_tuned_rfc_adbc': [0.695827613

],
    'ensemble_tuned_rfc_xgbc': [0.694935164

],    
    'gbm_regular': [0.686193745

],
    'gbm_tuned': [0.698413425

],
    'k_means': [0.34597254

],
    'knn': [0.688817696

],
    'lrc_regular': [0.705362319

],
    'lrc_tuned': [0.704492754

],
    'mlpc_tuned': [0.69317315

],
    'naive_bayes': [0.679992372

],
    'rfc_regular': [0.702776506

],
    'rfc_tuned': [0.698413425

],
    'svc_regular': [0.695797101

],
    'svc_tuned': [0.695797101

],
    'xgbc_regular': [0.666125095

],
    'xgbc_tuned': [0.676598017

] 
}

df = pd.DataFrame(data)
df *= 100
# Melt the DataFrame to a long format
df_melted = df.melt(var_name='Model', value_name='Recall')

# Plot a bar plot with all bars in blue
plt.figure(figsize=(30, 30))
sns.barplot(x='Model', y='Recall', data=df_melted, color='tab:blue')
# plt.yscale('log')
plt.title('Recall Results', fontsize=40)
plt.xlabel('Model', fontsize=40)
plt.xticks(rotation=45, ha='right')
plt.ylabel('Recall Range', fontsize=40)
plt.xticks(fontsize=40)
plt.yticks(fontsize=40)
plt.savefig('recall.png', dpi=300)
plt.show()
